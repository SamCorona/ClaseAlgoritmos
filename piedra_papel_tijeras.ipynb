# %%
print("--JUGADOR 1, SELECCIONA UNA OPCION--")
print("1.-Piedra")
print("2.-Papel")
print("3.-Tijeras")
print("4. lagarto")
print("5. spock")
jug1=int(input())

print("--JUGADOR 2, SELECCIONA UNA OPCION--")
print("1.-Piedra")
print("2.-Papel")
print("3.-Tijeras")
print("4. lagarto")
print("5. spock")

jug2=int(input())

if(jug1==1 and jug2==1):
  print("empate")
elif(jug1==1 and jug2==2):
  print("Gana jugador 2")
elif(jug1==1 and jug2==3):
  print("gana jugador 1")
elif(jug1==1 and jug2==4):
    print("gana jugador 1")
elif(jug1==1 and jug2==5):
    print("gana jugador 2")
elif(jug1==2 and jug2==1):
    print("gana jugador 1")
elif(jug1==2 and jug2==2):
    print("empate")
elif(jug1==2 and jug2==3):
    print("Gana jugador 2")
elif(jug1==2 and jug2==4):
    print("gana jugador 2")
elif(jug1==2 and jug2==5):
    print("gana jugador 1")
elif(jug1==3 and jug2==1):
    print("Gana jugador 2")
elif(jug1==3 and jug2==2):
    print("gana jugador 1")
elif(jug1==3 and jug2==3):
    print("empate")
elif(jug1==3 and jug2==4):
    print("gana jugador 1")
elif(jug1==3 and jug2==5):
    print("gana jugador 2")
elif(jug1==4 and jug2==1):
    print("gana jugador 2")
elif(jug1==4 and jug2==2):
    print("gana jugador 1")
elif(jug1==4 and jug2==3):
    print("gana jugador 2")
elif(jug1==4 and jug2==4):
    print("empate")
elif(jug1==4 and jug2==5):
    print("gana jugador 1")
elif(jug1==5 and jug2==1):
    print("gana jugador 1")
elif(jug1==5 and jug2==2):
    print("gana jugador 2")
elif(jug1==5 and jug2==3):
    print("gana jugardor 1")
elif(jug1==5 and jug2==4):
    print("gana jugador 2")
elif(jug1==5 and jug2==5):
    print("empate")
else:
    print("los datos no son validos")
# Out:
# --JUGADOR 1, SELECCIONA UNA OPCION--
# 1.-Piedra
# 2.-Papel
# 3.-Tijeras
# 4. lagarto
# 5. spock
# 3
# --JUGADOR 2, SELECCIONA UNA OPCION--
# 1.-Piedra
# 2.-Papel
# 3.-Tijeras
# 4. lagarto
# 5. spock
# 5
# gana jugador 2
