# %%
#Se establece el tamaño del arreglo
m=int(input("Ingresa el número de filas: ")) #Filas
n=int(input("Ingresa el número de columnas: ")) #Columnas

#Se crea el arreglo
A=[]

#Se crea una variable para establecer si es de Netflix o de Disney + que inicia vacía
valor=""

#Se inicializa el arreglo, es un proceso necesario para los arreglos bidimensionales
for i in range(m):
  A.append([0]*n)

#Inicia el proceso de llenado del arreglo bidimensional
for i in range (m):

  #Este if es auxiliar solamente para mostrar Netflix o Disney + en la captura
  if (i==0):
    valor="Netflix"
  else:
    valor="Disney +"

  for j in range (n):
    #Así se llena el arreglo bidimensional
    A[i][j]=input("Introduzca la serie "+str(j+1)+" de "+valor+": ")

#Se imprime el arreglo bidimensional
print(A)
# Out:
# Ingresa el número de filas: 2
# Ingresa el número de columnas: 2
# Introduzca la serie 1 de Netflix: Hola
# Introduzca la serie 2 de Netflix: Hola 2
# Introduzca la serie 1 de Disney +: Hola
# Introduzca la serie 2 de Disney +: Hola 2
# [['Hola', 'Hola 2'], ['Hola ', 'Hola 2']]

# %%
cat=4#(int(input("cuantas categorias se contemplaran: ")))
alu=(int(input("los datos de cuantos alumnos se compilaran: ")))

M="[i][j]"
H="[i][j]"
suma=""
prom=""
A=[]

valor=""

for i in range(alu):
  A.append([0]*cat)

for i in range(alu):
  for j in range(cat):

    if (j==0):
      valor="numero de control"
    elif(j==1):
      valor="nombre del alumno"
    elif(j==2):
      valor="calificacion"
    elif(j==3):
      valor="genero M/H"

    A[i][j]=input("introduzca el dato de "+valor+ ": " )


print(A)

Totalh=0
Totalm=0
Calh=0
Calm=0
Promedioh=0
Promediom=0

for i in range(0,alu):
  #print(A[i][2]) #Calificaciones
  #print(A[i][3]) #Gènero

  if(A[i][3]=='H'):
    Totalh=Totalh+1
    Calh=Calh+int(A[i][2])

  if(A[i][3]=='M'):
    Totalm=Totalm+1
    Calm=Calm+int(A[i][2])

Promedioh=Calh/Totalh
Promediom=Calm/Totalm

print(Promedioh)

print(Promediom)
# Out:
# los datos de cuantos alumnos se compilaran: 2
# introduzca el dato de numero de control: 321030102
# introduzca el dato de nombre del alumno: carlos
# introduzca el dato de calificacion: 10
# introduzca el dato de genero M/H: H
# introduzca el dato de numero de control: 321030101
# introduzca el dato de nombre del alumno: samanta
# introduzca el dato de calificacion: 7
# introduzca el dato de genero M/H: M
# [['321030102', 'carlos', '10', 'H'], ['321030101', 'samanta', '7', 'M']]
# 10.0
# 7.0
